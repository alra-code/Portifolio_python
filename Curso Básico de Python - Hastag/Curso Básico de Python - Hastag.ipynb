# %% [markdown]
# ##Passo a passo da solução do desafio

# %%
# Lógica de programação
# Passo 0 - Entender o desafio que você quer resolver
# Passo 1 - Percorrer todos os arquivos da pasta base de dados

#importações
import os
import pandas as pd
import plotly.express as px

lista_arquivo = os.listdir("/content/drive/MyDrive/Analista de Dados - Estudos /Cursos/Curso Básico de Python /Vendas")
display  (lista_arquivo)
# Out:
# ['Cópia de Devolucoes - Fortaleza.csv',
#  'Cópia de Devolucoes - Goiás.csv',
#  'Cópia de Devolucoes - São Paulo.csv',
#  'Cópia de Devolucoes - Salvador.csv',
#  'Cópia de Vendas - Belo Horizonte.csv',
#  'Cópia de Devolucoes - Curitiba.csv',
#  'Cópia de Devolucoes - Recife.csv',
#  'Cópia de Devolucoes - Porto Alegre.csv',
#  'Cópia de Devolucoes - Belo Horizonte.csv',
#  'Cópia de Devolucoes - Rio de Janeiro.csv',
#  'Cópia de Vendas - Recife.csv',
#  'Cópia de Vendas - Fortaleza.csv',
#  'Cópia de Vendas - Goiás.csv',
#  'Cópia de Vendas - Curitiba.csv',
#  'Cópia de Vendas - Salvador.csv',
#  'Cópia de Vendas - Porto Alegre.csv',
#  'Cópia de Vendas - Rio de Janeiro.csv',
#  'Cópia de Vendas - São Paulo.csv']

# %%
# Passo 2 - Importar as bases de dados de vendas
for arquivo in lista_arquivo:
  print(f"/content/drive/MyDrive/Analista de Dados - Estudos /Cursos/Curso Básico de Python /Vendas/{arquivo}")
# Out:
# /content/drive/MyDrive/Analista de Dados - Estudos /Cursos/Curso Básico de Python /Vendas/Cópia de Devolucoes - Fortaleza.csv
# /content/drive/MyDrive/Analista de Dados - Estudos /Cursos/Curso Básico de Python /Vendas/Cópia de Devolucoes - Goiás.csv
# /content/drive/MyDrive/Analista de Dados - Estudos /Cursos/Curso Básico de Python /Vendas/Cópia de Devolucoes - São Paulo.csv
# /content/drive/MyDrive/Analista de Dados - Estudos /Cursos/Curso Básico de Python /Vendas/Cópia de Devolucoes - Salvador.csv
# /content/drive/MyDrive/Analista de Dados - Estudos /Cursos/Curso Básico de Python /Vendas/Cópia de Vendas - Belo Horizonte.csv
# /content/drive/MyDrive/Analista de Dados - Estudos /Cursos/Curso Básico de Python /Vendas/Cópia de Devolucoes - Curitiba.csv
# /content/drive/MyDrive/Analista de Dados - Estudos /Cursos/Curso Básico de Python /Vendas/Cópia de Devolucoes - Recife.csv
# ...

# %%
# Passo 2 - Importar as bases de dados de vendas
for arquivo in lista_arquivo:
  # se tem vendas no nome do arquivo então:
  if "vendas" in arquivo.lower():
    print(f"/content/drive/MyDrive/Analista de Dados - Estudos /Cursos/Curso Básico de Python /Vendas/{arquivo}")
# Out:
# /content/drive/MyDrive/Analista de Dados - Estudos /Cursos/Curso Básico de Python /Vendas/Cópia de Vendas - Belo Horizonte.csv
# /content/drive/MyDrive/Analista de Dados - Estudos /Cursos/Curso Básico de Python /Vendas/Cópia de Vendas - Recife.csv
# /content/drive/MyDrive/Analista de Dados - Estudos /Cursos/Curso Básico de Python /Vendas/Cópia de Vendas - Fortaleza.csv
# /content/drive/MyDrive/Analista de Dados - Estudos /Cursos/Curso Básico de Python /Vendas/Cópia de Vendas - Goiás.csv
# /content/drive/MyDrive/Analista de Dados - Estudos /Cursos/Curso Básico de Python /Vendas/Cópia de Vendas - Curitiba.csv
# /content/drive/MyDrive/Analista de Dados - Estudos /Cursos/Curso Básico de Python /Vendas/Cópia de Vendas - Salvador.csv
# /content/drive/MyDrive/Analista de Dados - Estudos /Cursos/Curso Básico de Python /Vendas/Cópia de Vendas - Porto Alegre.csv
# ...

# %%
tabela_total = pd.DataFrame()
for arquivo in lista_arquivo:
  if "Vendas" in arquivo:
    tabela = pd.read_csv(f"/content/drive/MyDrive/Analista de Dados - Estudos /Cursos/Curso Básico de Python /Vendas/{arquivo}")
    tabela_total = pd.concat([tabela_total, tabela], ignore_index=True)

# %%
# Passo 3 - Tratar compilar as bases de dados
display(tabela_total)
# Out:
#       Unnamed: 0     SKU     Produto  Quantidade Vendida Primeiro Nome  \
# 0             17  HL4379   Televisão                   2      Carolina
# 1             25  HL4379   Televisão                   1        Danilo
# 2             27  HL1918      iPhone                   5       Bernard
# 3             54  HL1918      iPhone                   5         Lucas
# 4             67  HL8851    Notebook                   5      Bernardo
# ...          ...     ...         ...                 ...           ...
# 9994        9981  HL7348  SmartWatch                   4          João
# 9995        9984  HL1918      iPhone                   4          Itai
# 9996        9985  HL1918      iPhone                   1     Guilherme
# 9997        9991  HL7348  SmartWatch                   5       Antônio
# 9998        9996  HL4379   Televisão                   5          Caio
#
#        Sobrenome        Data            Loja  Preco Unitario  Unnamed: 8
# ...

# %%
# Passo 4 - Calcular o produto mais vendido ( em quantidade)
tabela_produtos = tabela_total.groupby("Produto").sum()
tabela_produtos = tabela_produtos[["Quantidade Vendida", "Preco Unitario"]].sort_values(by="Quantidade Vendida", ascending=False)
display(tabela_produtos)
# Out:
#             Quantidade Vendida  Preco Unitario
# Produto
# iPhone                    8974        15778100
# Televisão                 5931         4905000
# Notebook                  3249         3717000
# Android                   3183         3631200
# SmartWatch                2980         1393000
# Tablet                    2921         1556800
# Câmera                    2805         2020200

# %%
# Passo 5 - Calcular o produto que mais faturou ( em faturamento)
tabela_total["Faturamento"] = tabela_total["Quantidade Vendida"] * tabela_total["Preco Unitario"]
display(tabela_total)
# Out:
#       Unnamed: 0     SKU     Produto  Quantidade Vendida Primeiro Nome  \
# 0             17  HL4379   Televisão                   2      Carolina
# 1             25  HL4379   Televisão                   1        Danilo
# 2             27  HL1918      iPhone                   5       Bernard
# 3             54  HL1918      iPhone                   5         Lucas
# 4             67  HL8851    Notebook                   5      Bernardo
# ...          ...     ...         ...                 ...           ...
# 9994        9981  HL7348  SmartWatch                   4          João
# 9995        9984  HL1918      iPhone                   4          Itai
# 9996        9985  HL1918      iPhone                   1     Guilherme
# 9997        9991  HL7348  SmartWatch                   5       Antônio
# 9998        9996  HL4379   Televisão                   5          Caio
#
#        Sobrenome        Data            Loja  Preco Unitario  Unnamed: 8  \
# ...

# %%
tabela_faturamento = tabela_total.groupby("Produto").sum()
tabela_faturamento = tabela_faturamento[["Faturamento"]].sort_values(by="Faturamento", ascending=False)
display(tabela_faturamento)
# Out:
#             Faturamento
# Produto
# iPhone         47562200
# Televisão      14827500
# Notebook       11371500
# Android        10822200
# Câmera          5890500
# Tablet          4673600
# SmartWatch      4172000

# %%
# Passo 6 - Calcular loja / cidade que mais vendeu ( em faturamento) - criar gráfico e Dashboard
tabela_lojas = tabela_total.groupby("Loja").sum()
tabela_lojas = tabela_lojas[["Faturamento"]]
display(tabela_lojas)
# Out:
#                 Faturamento
# Loja
# Belo Horizonte      6480300
# Curitiba            7060500
# Fortaleza          14087900
# Goiás               7441800
# Porto Alegre        6868600
# Recife              7303000
# Rio de Janeiro     14867800
# Salvador           13111300
# São Paulo          22098300

# %%
grafico = px.bar(tabela_lojas, x=tabela_lojas.index, y="Faturamento")
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# junção das tabelas
tabela_final = pd.merge(tabela_faturamento, tabela_produtos, on="Produto")
display(tabela_final)
# Out:
#             Faturamento  Quantidade Vendida  Preco Unitario
# Produto
# iPhone         47562200                8974        15778100
# Televisão      14827500                5931         4905000
# Notebook       11371500                3249         3717000
# Android        10822200                3183         3631200
# Câmera          5890500                2805         2020200
# Tablet          4673600                2921         1556800
# SmartWatch      4172000                2980         1393000

# %%
# baixar a tabela final e total em formato excel
tabela_final.to_excel("tabela_final.xlsx", index=False)

# %%
tabela_total.to_excel("tabela_total.xlsx", index=False)
